# %% [markdown]
# # 11 — Run All Notebooks
#
# Ejecuta toda la secuencia en orden usando papermill.
# Los outputs ejecutados se guardan en `outputs/notebook_runs/`.

# %%
import sys
from pathlib import Path
import subprocess

PROJECT_ROOT = Path.cwd().parent
script = PROJECT_ROOT / 'scripts' / 'run_all_notebooks.py'

if not script.exists():
    raise FileNotFoundError(script)

cmd = [sys.executable, str(script)]
print('Running:', ' '.join(cmd))
subprocess.check_call(cmd)
