# %% [markdown]
# # 11 — Run All Notebooks
#
# Ejecuta toda la secuencia en orden usando papermill.
# Los outputs ejecutados se guardan en `outputs/notebook_runs/`.

# %%
import sys
from pathlib import Path
import subprocess

PROJECT_ROOT = Path.cwd().parent
script = PROJECT_ROOT / 'scripts' / 'run_all_notebooks.py'

if not script.exists():
    raise FileNotFoundError(script)

cmd = [sys.executable, str(script)]
print('Running:', ' '.join(cmd))
subprocess.check_call(cmd)
# Out:
# Running: /home/sagemaker-user/.venv/bin/python /home/sagemaker-user/TFMAXEL/scripts/run_all_notebooks.py
# Running: /home/sagemaker-user/TFMAXEL/notebooks/00_setup_and_gpu_check.ipynb -> /home/sagemaker-user/TFMAXEL/outputs/notebook_runs/00_setup_and_gpu_check.ipynb
# Executor: papermill
# Executing:   0%|          | 0/10 [00:00<?, ?cell/s][IPKernelApp] WARNING | Error in loading extension: sagemaker_sparkmonitor.kernelextension
# Check your config files in /home/sagemaker-user/.ipython/profile_default
# Traceback (most recent call last):
#   File "/home/sagemaker-user/.venv/lib/python3.11/site-packages/IPython/core/shellapp.py", line 331, in init_extensions
#     self.shell.extension_manager.load_extension(ext)
#   File "/home/sagemaker-user/.venv/lib/python3.11/site-packages/IPython/core/extensions.py", line 62, in load_extension
#     return self._load_extension(module_str)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/sagemaker-user/.venv/lib/python3.11/site-packages/IPython/core/extensions.py", line 77, in _load_extension
#     mod = import_module(module_str)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 1204, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1176, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1126, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1204, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1176, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1140, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'sagemaker_sparkmonitor'
# [IPKernelApp] WARNING | Error in loading extension: sagemaker_studio_dataengineering_sessions.sagemaker_connection_magic
# Check your config files in /home/sagemaker-user/.ipython/profile_default
# Traceback (most recent call last):
#   File "/home/sagemaker-user/.venv/lib/python3.11/site-packages/IPython/core/shellapp.py", line 331, in init_extensions
#     self.shell.extension_manager.load_extension(ext)
#   File "/home/sagemaker-user/.venv/lib/python3.11/site-packages/IPython/core/extensions.py", line 62, in load_extension
#     return self._load_extension(module_str)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/sagemaker-user/.venv/lib/python3.11/site-packages/IPython/core/extensions.py", line 77, in _load_extension
#     mod = import_module(module_str)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 1204, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1176, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1126, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1204, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1176, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1140, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'sagemaker_studio_dataengineering_sessions'
# Executing: 100%|██████████| 10/10 [00:04<00:00,  2.19cell/s]
# Executing:   0%|          | 0/23 [00:00<?, ?cell/s]
# Running: /home/sagemaker-user/TFMAXEL/notebooks/01_Setup_and_Data_Audit.ipynb -> /home/sagemaker-user/TFMAXEL/outputs/notebook_runs/01_Setup_and_Data_Audit.ipynb
# Executor: papermill
# [IPKernelApp] WARNING | Error in loading extension: sagemaker_sparkmonitor.kernelextension
# Check your config files in /home/sagemaker-user/.ipython/profile_default
# Traceback (most recent call last):
#   File "/home/sagemaker-user/.venv/lib/python3.11/site-packages/IPython/core/shellapp.py", line 331, in init_extensions
#     self.shell.extension_manager.load_extension(ext)
#   File "/home/sagemaker-user/.venv/lib/python3.11/site-packages/IPython/core/extensions.py", line 62, in load_extension
#     return self._load_extension(module_str)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/sagemaker-user/.venv/lib/python3.11/site-packages/IPython/core/extensions.py", line 77, in _load_extension
#     mod = import_module(module_str)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 1204, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1176, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1126, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1204, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1176, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1140, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'sagemaker_sparkmonitor'
# [IPKernelApp] WARNING | Error in loading extension: sagemaker_studio_dataengineering_sessions.sagemaker_connection_magic
# Check your config files in /home/sagemaker-user/.ipython/profile_default
# Traceback (most recent call last):
#   File "/home/sagemaker-user/.venv/lib/python3.11/site-packages/IPython/core/shellapp.py", line 331, in init_extensions
#     self.shell.extension_manager.load_extension(ext)
#   File "/home/sagemaker-user/.venv/lib/python3.11/site-packages/IPython/core/extensions.py", line 62, in load_extension
#     return self._load_extension(module_str)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/sagemaker-user/.venv/lib/python3.11/site-packages/IPython/core/extensions.py", line 77, in _load_extension
#     mod = import_module(module_str)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 1204, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1176, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1126, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1204, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1176, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1140, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'sagemaker_studio_dataengineering_sessions'
# Executing: 100%|██████████| 23/23 [00:01<00:00, 14.13cell/s]
# Executing:   0%|          | 0/12 [00:00<?, ?cell/s]
# Running: /home/sagemaker-user/TFMAXEL/notebooks/02_data_and_feature_sets.ipynb -> /home/sagemaker-user/TFMAXEL/outputs/notebook_runs/02_data_and_feature_sets.ipynb
# Executor: papermill
# [IPKernelApp] WARNING | Error in loading extension: sagemaker_sparkmonitor.kernelextension
# Check your config files in /home/sagemaker-user/.ipython/profile_default
# Traceback (most recent call last):
#   File "/home/sagemaker-user/.venv/lib/python3.11/site-packages/IPython/core/shellapp.py", line 331, in init_extensions
#     self.shell.extension_manager.load_extension(ext)
#   File "/home/sagemaker-user/.venv/lib/python3.11/site-packages/IPython/core/extensions.py", line 62, in load_extension
#     return self._load_extension(module_str)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/sagemaker-user/.venv/lib/python3.11/site-packages/IPython/core/extensions.py", line 77, in _load_extension
#     mod = import_module(module_str)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 1204, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1176, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1126, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1204, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1176, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1140, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'sagemaker_sparkmonitor'
# [IPKernelApp] WARNING | Error in loading extension: sagemaker_studio_dataengineering_sessions.sagemaker_connection_magic
# Check your config files in /home/sagemaker-user/.ipython/profile_default
# Traceback (most recent call last):
#   File "/home/sagemaker-user/.venv/lib/python3.11/site-packages/IPython/core/shellapp.py", line 331, in init_extensions
#     self.shell.extension_manager.load_extension(ext)
#   File "/home/sagemaker-user/.venv/lib/python3.11/site-packages/IPython/core/extensions.py", line 62, in load_extension
#     return self._load_extension(module_str)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/sagemaker-user/.venv/lib/python3.11/site-packages/IPython/core/extensions.py", line 77, in _load_extension
#     mod = import_module(module_str)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 1204, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1176, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1126, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1204, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1176, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1140, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'sagemaker_studio_dataengineering_sessions'
# Executing: 100%|██████████| 12/12 [00:01<00:00,  8.53cell/s]
# Executing:   0%|          | 0/16 [00:00<?, ?cell/s]
# Running: /home/sagemaker-user/TFMAXEL/notebooks/03_SARIMAX_exog.ipynb -> /home/sagemaker-user/TFMAXEL/outputs/notebook_runs/03_SARIMAX_exog.ipynb
# Executor: papermill
# [IPKernelApp] WARNING | Error in loading extension: sagemaker_sparkmonitor.kernelextension
# Check your config files in /home/sagemaker-user/.ipython/profile_default
# Traceback (most recent call last):
#   File "/home/sagemaker-user/.venv/lib/python3.11/site-packages/IPython/core/shellapp.py", line 331, in init_extensions
#     self.shell.extension_manager.load_extension(ext)
#   File "/home/sagemaker-user/.venv/lib/python3.11/site-packages/IPython/core/extensions.py", line 62, in load_extension
#     return self._load_extension(module_str)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/sagemaker-user/.venv/lib/python3.11/site-packages/IPython/core/extensions.py", line 77, in _load_extension
#     mod = import_module(module_str)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 1204, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1176, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1126, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1204, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1176, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1140, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'sagemaker_sparkmonitor'
# [IPKernelApp] WARNING | Error in loading extension: sagemaker_studio_dataengineering_sessions.sagemaker_connection_magic
# Check your config files in /home/sagemaker-user/.ipython/profile_default
# Traceback (most recent call last):
#   File "/home/sagemaker-user/.venv/lib/python3.11/site-packages/IPython/core/shellapp.py", line 331, in init_extensions
#     self.shell.extension_manager.load_extension(ext)
#   File "/home/sagemaker-user/.venv/lib/python3.11/site-packages/IPython/core/extensions.py", line 62, in load_extension
#     return self._load_extension(module_str)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/sagemaker-user/.venv/lib/python3.11/site-packages/IPython/core/extensions.py", line 77, in _load_extension
#     mod = import_module(module_str)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 1204, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1176, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1126, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1204, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1176, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1140, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'sagemaker_studio_dataengineering_sessions'
# Executing: 100%|██████████| 16/16 [00:05<00:00,  2.79cell/s]
# Executing:   0%|          | 0/16 [00:00<?, ?cell/s]
# Running: /home/sagemaker-user/TFMAXEL/notebooks/04_Prophet_regressors.ipynb -> /home/sagemaker-user/TFMAXEL/outputs/notebook_runs/04_Prophet_regressors.ipynb
# Executor: papermill
# [IPKernelApp] WARNING | Error in loading extension: sagemaker_sparkmonitor.kernelextension
# Check your config files in /home/sagemaker-user/.ipython/profile_default
# Traceback (most recent call last):
#   File "/home/sagemaker-user/.venv/lib/python3.11/site-packages/IPython/core/shellapp.py", line 331, in init_extensions
#     self.shell.extension_manager.load_extension(ext)
#   File "/home/sagemaker-user/.venv/lib/python3.11/site-packages/IPython/core/extensions.py", line 62, in load_extension
#     return self._load_extension(module_str)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/sagemaker-user/.venv/lib/python3.11/site-packages/IPython/core/extensions.py", line 77, in _load_extension
#     mod = import_module(module_str)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 1204, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1176, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1126, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1204, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1176, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1140, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'sagemaker_sparkmonitor'
# [IPKernelApp] WARNING | Error in loading extension: sagemaker_studio_dataengineering_sessions.sagemaker_connection_magic
# Check your config files in /home/sagemaker-user/.ipython/profile_default
# Traceback (most recent call last):
#   File "/home/sagemaker-user/.venv/lib/python3.11/site-packages/IPython/core/shellapp.py", line 331, in init_extensions
#     self.shell.extension_manager.load_extension(ext)
#   File "/home/sagemaker-user/.venv/lib/python3.11/site-packages/IPython/core/extensions.py", line 62, in load_extension
#     return self._load_extension(module_str)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/sagemaker-user/.venv/lib/python3.11/site-packages/IPython/core/extensions.py", line 77, in _load_extension
#     mod = import_module(module_str)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 1204, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1176, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1126, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1204, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1176, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1140, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'sagemaker_studio_dataengineering_sessions'
# Executing: 100%|██████████| 16/16 [00:03<00:00,  4.32cell/s]
# Executing:   0%|          | 0/18 [00:00<?, ?cell/s]
# Running: /home/sagemaker-user/TFMAXEL/notebooks/05_GluonTS_DeepAR_exog.ipynb -> /home/sagemaker-user/TFMAXEL/outputs/notebook_runs/05_GluonTS_DeepAR_exog.ipynb
# Executor: papermill
# [IPKernelApp] WARNING | Error in loading extension: sagemaker_sparkmonitor.kernelextension
# Check your config files in /home/sagemaker-user/.ipython/profile_default
# Traceback (most recent call last):
#   File "/home/sagemaker-user/.venv/lib/python3.11/site-packages/IPython/core/shellapp.py", line 331, in init_extensions
#     self.shell.extension_manager.load_extension(ext)
#   File "/home/sagemaker-user/.venv/lib/python3.11/site-packages/IPython/core/extensions.py", line 62, in load_extension
#     return self._load_extension(module_str)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/sagemaker-user/.venv/lib/python3.11/site-packages/IPython/core/extensions.py", line 77, in _load_extension
#     mod = import_module(module_str)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 1204, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1176, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1126, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1204, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1176, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1140, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'sagemaker_sparkmonitor'
# [IPKernelApp] WARNING | Error in loading extension: sagemaker_studio_dataengineering_sessions.sagemaker_connection_magic
# Check your config files in /home/sagemaker-user/.ipython/profile_default
# Traceback (most recent call last):
#   File "/home/sagemaker-user/.venv/lib/python3.11/site-packages/IPython/core/shellapp.py", line 331, in init_extensions
#     self.shell.extension_manager.load_extension(ext)
#   File "/home/sagemaker-user/.venv/lib/python3.11/site-packages/IPython/core/extensions.py", line 62, in load_extension
#     return self._load_extension(module_str)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/sagemaker-user/.venv/lib/python3.11/site-packages/IPython/core/extensions.py", line 77, in _load_extension
#     mod = import_module(module_str)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 1204, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1176, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1126, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1204, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1176, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1140, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'sagemaker_studio_dataengineering_sessions'
# Executing: 100%|██████████| 18/18 [07:04<00:00, 23.56s/cell]
# Running: /home/sagemaker-user/TFMAXEL/notebooks/06_LSTM_global_exog.ipynb -> /home/sagemaker-user/TFMAXEL/outputs/notebook_runs/06_LSTM_global_exog.ipynb
# Executor: papermill
# Executing:   0%|          | 0/20 [00:00<?, ?cell/s][IPKernelApp] WARNING | Error in loading extension: sagemaker_sparkmonitor.kernelextension
# Check your config files in /home/sagemaker-user/.ipython/profile_default
# Traceback (most recent call last):
#   File "/home/sagemaker-user/.venv/lib/python3.11/site-packages/IPython/core/shellapp.py", line 331, in init_extensions
#     self.shell.extension_manager.load_extension(ext)
#   File "/home/sagemaker-user/.venv/lib/python3.11/site-packages/IPython/core/extensions.py", line 62, in load_extension
#     return self._load_extension(module_str)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/sagemaker-user/.venv/lib/python3.11/site-packages/IPython/core/extensions.py", line 77, in _load_extension
#     mod = import_module(module_str)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 1204, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1176, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1126, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1204, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1176, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1140, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'sagemaker_sparkmonitor'
# [IPKernelApp] WARNING | Error in loading extension: sagemaker_studio_dataengineering_sessions.sagemaker_connection_magic
# Check your config files in /home/sagemaker-user/.ipython/profile_default
# Traceback (most recent call last):
#   File "/home/sagemaker-user/.venv/lib/python3.11/site-packages/IPython/core/shellapp.py", line 331, in init_extensions
#     self.shell.extension_manager.load_extension(ext)
#   File "/home/sagemaker-user/.venv/lib/python3.11/site-packages/IPython/core/extensions.py", line 62, in load_extension
#     return self._load_extension(module_str)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/sagemaker-user/.venv/lib/python3.11/site-packages/IPython/core/extensions.py", line 77, in _load_extension
#     mod = import_module(module_str)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 1204, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1176, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1126, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1204, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1176, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1140, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'sagemaker_studio_dataengineering_sessions'
# Executing: 100%|██████████| 20/20 [00:06<00:00,  3.15cell/s]
# Executing:   0%|          | 0/20 [00:00<?, ?cell/s]
# Running: /home/sagemaker-user/TFMAXEL/notebooks/07_Transformer_global_exog.ipynb -> /home/sagemaker-user/TFMAXEL/outputs/notebook_runs/07_Transformer_global_exog.ipynb
# Executor: papermill
# [IPKernelApp] WARNING | Error in loading extension: sagemaker_sparkmonitor.kernelextension
# Check your config files in /home/sagemaker-user/.ipython/profile_default
# Traceback (most recent call last):
#   File "/home/sagemaker-user/.venv/lib/python3.11/site-packages/IPython/core/shellapp.py", line 331, in init_extensions
#     self.shell.extension_manager.load_extension(ext)
#   File "/home/sagemaker-user/.venv/lib/python3.11/site-packages/IPython/core/extensions.py", line 62, in load_extension
#     return self._load_extension(module_str)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/sagemaker-user/.venv/lib/python3.11/site-packages/IPython/core/extensions.py", line 77, in _load_extension
#     mod = import_module(module_str)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 1204, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1176, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1126, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1204, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1176, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1140, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'sagemaker_sparkmonitor'
# [IPKernelApp] WARNING | Error in loading extension: sagemaker_studio_dataengineering_sessions.sagemaker_connection_magic
# Check your config files in /home/sagemaker-user/.ipython/profile_default
# Traceback (most recent call last):
#   File "/home/sagemaker-user/.venv/lib/python3.11/site-packages/IPython/core/shellapp.py", line 331, in init_extensions
#     self.shell.extension_manager.load_extension(ext)
#   File "/home/sagemaker-user/.venv/lib/python3.11/site-packages/IPython/core/extensions.py", line 62, in load_extension
#     return self._load_extension(module_str)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/sagemaker-user/.venv/lib/python3.11/site-packages/IPython/core/extensions.py", line 77, in _load_extension
#     mod = import_module(module_str)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 1204, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1176, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1126, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1204, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1176, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1140, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'sagemaker_studio_dataengineering_sessions'
# Executing: 100%|██████████| 20/20 [00:41<00:00,  2.07s/cell]
# Executing:   0%|          | 0/15 [00:00<?, ?cell/s]
# Running: /home/sagemaker-user/TFMAXEL/notebooks/08_run_E0_ablation_training.ipynb -> /home/sagemaker-user/TFMAXEL/outputs/notebook_runs/08_run_E0_ablation_training.ipynb
# Executor: papermill
# [IPKernelApp] WARNING | Error in loading extension: sagemaker_sparkmonitor.kernelextension
# Check your config files in /home/sagemaker-user/.ipython/profile_default
# Traceback (most recent call last):
#   File "/home/sagemaker-user/.venv/lib/python3.11/site-packages/IPython/core/shellapp.py", line 331, in init_extensions
#     self.shell.extension_manager.load_extension(ext)
#   File "/home/sagemaker-user/.venv/lib/python3.11/site-packages/IPython/core/extensions.py", line 62, in load_extension
#     return self._load_extension(module_str)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/sagemaker-user/.venv/lib/python3.11/site-packages/IPython/core/extensions.py", line 77, in _load_extension
#     mod = import_module(module_str)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 1204, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1176, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1126, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1204, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1176, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1140, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'sagemaker_sparkmonitor'
# [IPKernelApp] WARNING | Error in loading extension: sagemaker_studio_dataengineering_sessions.sagemaker_connection_magic
# Check your config files in /home/sagemaker-user/.ipython/profile_default
# Traceback (most recent call last):
#   File "/home/sagemaker-user/.venv/lib/python3.11/site-packages/IPython/core/shellapp.py", line 331, in init_extensions
#     self.shell.extension_manager.load_extension(ext)
#   File "/home/sagemaker-user/.venv/lib/python3.11/site-packages/IPython/core/extensions.py", line 62, in load_extension
#     return self._load_extension(module_str)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/sagemaker-user/.venv/lib/python3.11/site-packages/IPython/core/extensions.py", line 77, in _load_extension
#     mod = import_module(module_str)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 1204, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1176, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1126, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1204, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1176, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1140, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'sagemaker_studio_dataengineering_sessions'
# Executing: 100%|██████████| 15/15 [00:42<00:00,  2.80s/cell]
# Executing:   0%|          | 0/12 [00:00<?, ?cell/s]
# Running: /home/sagemaker-user/TFMAXEL/notebooks/09_results_summary_and_plots.ipynb -> /home/sagemaker-user/TFMAXEL/outputs/notebook_runs/09_results_summary_and_plots.ipynb
# Executor: papermill
# [IPKernelApp] WARNING | Error in loading extension: sagemaker_sparkmonitor.kernelextension
# Check your config files in /home/sagemaker-user/.ipython/profile_default
# Traceback (most recent call last):
#   File "/home/sagemaker-user/.venv/lib/python3.11/site-packages/IPython/core/shellapp.py", line 331, in init_extensions
#     self.shell.extension_manager.load_extension(ext)
#   File "/home/sagemaker-user/.venv/lib/python3.11/site-packages/IPython/core/extensions.py", line 62, in load_extension
#     return self._load_extension(module_str)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/sagemaker-user/.venv/lib/python3.11/site-packages/IPython/core/extensions.py", line 77, in _load_extension
#     mod = import_module(module_str)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 1204, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1176, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1126, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1204, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1176, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1140, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'sagemaker_sparkmonitor'
# [IPKernelApp] WARNING | Error in loading extension: sagemaker_studio_dataengineering_sessions.sagemaker_connection_magic
# Check your config files in /home/sagemaker-user/.ipython/profile_default
# Traceback (most recent call last):
#   File "/home/sagemaker-user/.venv/lib/python3.11/site-packages/IPython/core/shellapp.py", line 331, in init_extensions
#     self.shell.extension_manager.load_extension(ext)
#   File "/home/sagemaker-user/.venv/lib/python3.11/site-packages/IPython/core/extensions.py", line 62, in load_extension
#     return self._load_extension(module_str)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/sagemaker-user/.venv/lib/python3.11/site-packages/IPython/core/extensions.py", line 77, in _load_extension
#     mod = import_module(module_str)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 1204, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1176, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1126, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1204, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1176, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1140, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'sagemaker_studio_dataengineering_sessions'
# Executing: 100%|██████████| 12/12 [00:04<00:00,  2.77cell/s]
# Executing:   0%|          | 0/23 [00:00<?, ?cell/s]
# Running: /home/sagemaker-user/TFMAXEL/notebooks/10_Run_All_Experiments.ipynb -> /home/sagemaker-user/TFMAXEL/outputs/notebook_runs/10_Run_All_Experiments.ipynb
# Executor: papermill
# [IPKernelApp] WARNING | Error in loading extension: sagemaker_sparkmonitor.kernelextension
# Check your config files in /home/sagemaker-user/.ipython/profile_default
# Traceback (most recent call last):
#   File "/home/sagemaker-user/.venv/lib/python3.11/site-packages/IPython/core/shellapp.py", line 331, in init_extensions
#     self.shell.extension_manager.load_extension(ext)
#   File "/home/sagemaker-user/.venv/lib/python3.11/site-packages/IPython/core/extensions.py", line 62, in load_extension
#     return self._load_extension(module_str)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/sagemaker-user/.venv/lib/python3.11/site-packages/IPython/core/extensions.py", line 77, in _load_extension
#     mod = import_module(module_str)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 1204, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1176, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1126, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1204, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1176, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1140, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'sagemaker_sparkmonitor'
# [IPKernelApp] WARNING | Error in loading extension: sagemaker_studio_dataengineering_sessions.sagemaker_connection_magic
# Check your config files in /home/sagemaker-user/.ipython/profile_default
# Traceback (most recent call last):
#   File "/home/sagemaker-user/.venv/lib/python3.11/site-packages/IPython/core/shellapp.py", line 331, in init_extensions
#     self.shell.extension_manager.load_extension(ext)
#   File "/home/sagemaker-user/.venv/lib/python3.11/site-packages/IPython/core/extensions.py", line 62, in load_extension
#     return self._load_extension(module_str)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/sagemaker-user/.venv/lib/python3.11/site-packages/IPython/core/extensions.py", line 77, in _load_extension
#     mod = import_module(module_str)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 1204, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1176, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1126, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1204, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1176, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1140, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'sagemaker_studio_dataengineering_sessions'
# Executing:  48%|████▊     | 11/23 [00:14<00:01,  6.46cell/s]
